# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a = deque([1])
a.extendleft([1,2,3])
a
# Out:
# deque([3, 2, 1, 1])

# %%
n,m,v = map(int, input().split())
lines = [list(map(int, input().split())) for _ in range(m)]
graph = [[] for i in range(n+1) ]
for a,b in lines:
    graph[a].append(b)
    graph[b].append(a)
for i in graph:
    i.sort()

def dfs(v):
    work =[v]
    
    while work:
        dot = work.pop(0)
        if visited[dot]==0:
            work = graph[dot] + work
            print(dot, end=' ')
            visited[dot]=1
    print()
def bfs(v):
    work =[v]
    
    while work:
        dot = work.pop(0)
        if visited[dot]==0:
            work = work + graph[dot]
            print(dot, end=' ')
            visited[dot]=1
    print()
visited = [0]*(n+1)
dfs(v)
visited = [0]*(n+1)
bfs(v)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_1928/2798925215.py in <module>
# ----> 1 n,m,v = map(int, input().split())
#       2 lines = [list(map(int, input().split())) for _ in range(m)]
#       3 graph = [[] for i in range(n+1) ]
#       4 for a,b in lines:
#       5     graph[a].append(b)
#
# /usr/lib/python3/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1042                 "raw_input was called, but this frontend does not support input requests."
#    1043             )
# -> 1044         return self._input_request(
#    1045             str(prompt),
#    1046             self._parent_ident["shell"],
#
# /usr/lib/python3/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1087             except KeyboardInterrupt:
#    1088                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1089                 raise KeyboardInterrupt("Interrupted by user") from None
#    1090             except Exception:
#    1091                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
