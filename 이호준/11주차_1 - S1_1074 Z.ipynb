# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 0
# 1
# 100
# 101
# 10000
# 10001
# 10100
# 10101
# 100000
# 100001

# %%
n,r,c = map(int,input().split())
print(int(format(r, 'b'),4)*2+ int(format(c, 'b'),4))
