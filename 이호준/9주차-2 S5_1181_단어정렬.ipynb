# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 아이디어
# * 딕셔너리를 사용하여 중복처리를 해결하고 길이정보를 저장함
# * zip과 sorted를 사용하여 정렬 후 출력
#
# * 이전 풀이에서는 딕셔너리 대신 단순히 리스트와 set를 사용했었음(발전햇음! 뿌듯)

# %%
a=dict()
for _ in range(int(input())):
    b = input()
    a[b]=len(b)
for v, k in sorted(zip(a.values(),a.keys())):
    print(k)
# Out:
# 2
# it
# but
