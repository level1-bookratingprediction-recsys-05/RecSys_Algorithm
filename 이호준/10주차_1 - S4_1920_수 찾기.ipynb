# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# import sys
# input = sys.stdin.readline
input()
a = set(map(int, input().split()))
input()
print(*map(int, map(a.__contains__, map(int, input().split()))), sep='\n')

# %% [markdown]
# 고수풀이

# %%
u,n,l,m=open(0);n={*n.split()}
for i in m.split():print(+(i in n))
