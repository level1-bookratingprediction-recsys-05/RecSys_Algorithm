# %% [markdown]
# ![image.png](attachment:image.png)

# %%
dp = [[1,0], [0,1]]
for _ in range(int(input())):
    n = int(input())
    for i in range(max(2,len(dp)), n+1):
        dp.append([dp[i-1][0] + dp[i-2][0], dp[i-1][1] + dp[i-2][1]])
    print(*dp[n])
# Out:
# 2
# 6
# 5 8
# 22
# 10946 17711
