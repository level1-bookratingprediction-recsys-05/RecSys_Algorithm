# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# import sys
# input = sys.stdin.readline
nums =[False]*2_000_001

for _ in range(int(input())):
    nums[int(input())] = True
for i in range(-1_000_000,1_000_001):
    if nums[i]:
        print(i)
# Out:
# 5
# -2
# -1
# 5
# 1
# 2
# -2
# -1
# 1
# 2
# 5
